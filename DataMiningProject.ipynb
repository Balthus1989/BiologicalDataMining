# %% [markdown]
# # Data Mining Laboratory
# Group 4: Damiano Chini, Riccardo Gilmozzi, Gianmarco Piccinno & Alessandro Rizzuto

# %% [markdown]
# This code operates the preprocessing steps, namely (from the paper):
#
# 1) Probes containing missing values are excluded from the analysis.
#
# 2) Probes are mapped to Entrez ID labels if they are available in the associated platform. 3) Values corresponding to raw expression counts or gene expression intensity are log2 transformed (if necessary).
#
# 4) Probes mapping to the same Entrez ID label are averaged out.
#
# 5) Probes that cannot be mapped to a unique Entrez ID label are excluded from the analysis, as well as those that cannot be mapped to any Entrez ID label at all.
#
# 6) We apply a simple L 1 normalization in linear space, imposing that the sum of expression of all genes is constant among samples.
#
# After these steps, each data set or batch is represented by a single expression matrix X. Each entry X i j represents the log 2 of the expression intensity of gene i in sample j.

# %%
import GEOparse
import pandas as pd
import numpy as np
from  functools import *
import re

# %%
list_data = ["GSE2508", "GSE26637", "GSE27949", "GSE48964"]
gse1 = GEOparse.get_GEO(filepath="./data/GSE2508_family.soft.gz")
gse2 = GEOparse.get_GEO(filepath="./data/GSE26637_family.soft.gz")
gse3 = GEOparse.get_GEO(filepath="./data/GSE27949_family.soft.gz")
gse4 = GEOparse.get_GEO(filepath="./data/GSE48964_family.soft.gz")
# Out:
# 09-Oct-2017 16:22:19 INFO GEOparse - Parsing ./data/GSE2508_family.soft.gz:
# 09-Oct-2017 16:22:19 DEBUG GEOparse - DATABASE: GeoMiame
# 09-Oct-2017 16:22:19 DEBUG GEOparse - SERIES: GSE2508
# 09-Oct-2017 16:22:19 DEBUG GEOparse - PLATFORM: GPL91
# 09-Oct-2017 16:22:20 DEBUG GEOparse - PLATFORM: GPL92
# 09-Oct-2017 16:22:20 DEBUG GEOparse - PLATFORM: GPL93
# 09-Oct-2017 16:22:20 DEBUG GEOparse - PLATFORM: GPL94
# 09-Oct-2017 16:22:20 DEBUG GEOparse - PLATFORM: GPL95
# 09-Oct-2017 16:22:21 DEBUG GEOparse - PLATFORM: GPL8300
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47224
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47225
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47226
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47227
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47228
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47229
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47230
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47231
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47232
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47233
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47234
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47235
# 09-Oct-2017 16:22:21 DEBUG GEOparse - SAMPLE: GSM47242
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47256
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47269
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47286
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47299
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47300
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47301
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47303
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47317
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47319
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47321
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47322
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47323
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47324
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47325
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47326
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47327
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47328
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47329
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47330
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47331
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47332
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47333
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47334
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47335
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47336
# 09-Oct-2017 16:22:22 DEBUG GEOparse - SAMPLE: GSM47337
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47347
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47348
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47349
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47350
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47351
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47352
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47353
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47354
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47355
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47356
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47357
# 09-Oct-2017 16:22:23 DEBUG GEOparse - SAMPLE: GSM47358
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47570
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47571
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47572
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47573
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47574
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47575
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47576
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47577
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47578
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47579
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47580
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47581
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47582
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47583
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47584
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47585
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47586
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47587
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47588
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47589
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47590
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47591
# 09-Oct-2017 16:22:26 DEBUG GEOparse - SAMPLE: GSM47592
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47593
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47594
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47595
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47596
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47597
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47598
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47599
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47823
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47824
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47825
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47826
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47827
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47828
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47829
# 09-Oct-2017 16:22:27 DEBUG GEOparse - SAMPLE: GSM47830
DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   gpls[entry_name] = parse_GPL(data_group, entry_name)
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655603
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655604
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655605
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655606
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655607
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655608
# 09-Oct-2017 16:22:30 DEBUG GEOparse - SAMPLE: GSM655609
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655610
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655611
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655612
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655613
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655614
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655615
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655616
# 09-Oct-2017 16:22:31 DEBUG GEOparse - SAMPLE: GSM655617
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SAMPLE: GSM655618
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SAMPLE: GSM655619
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SAMPLE: GSM655620
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SAMPLE: GSM655621
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SAMPLE: GSM655622
# 09-Oct-2017 16:22:32 INFO GEOparse - Parsing ./data/GSE27949_family.soft.gz:
# 09-Oct-2017 16:22:32 DEBUG GEOparse - DATABASE: GeoMiame
# 09-Oct-2017 16:22:32 DEBUG GEOparse - SERIES: GSE27949
# 09-Oct-2017 16:22:32 DEBUG GEOparse - PLATFORM: GPL570
# 09-Oct-2017 16:22:34 DEBUG GEOparse - SAMPLE: GSM691122
# 09-Oct-2017 16:22:34 DEBUG GEOparse - SAMPLE: GSM691123
# 09-Oct-2017 16:22:34 DEBUG GEOparse - SAMPLE: GSM691124
# 09-Oct-2017 16:22:34 DEBUG GEOparse - SAMPLE: GSM691125
# 09-Oct-2017 16:22:34 DEBUG GEOparse - SAMPLE: GSM691126
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691127
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691128
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691129
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691130
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691131
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691132
# 09-Oct-2017 16:22:35 DEBUG GEOparse - SAMPLE: GSM691133
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691134
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691135
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691136
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691137
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691138
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691139
# 09-Oct-2017 16:22:36 DEBUG GEOparse - SAMPLE: GSM691140
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691141
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691142
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691143
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691144
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691145
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691146
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691147
# 09-Oct-2017 16:22:37 DEBUG GEOparse - SAMPLE: GSM691148
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691149
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691150
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691151
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691152
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691153
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SAMPLE: GSM691154
# 09-Oct-2017 16:22:38 INFO GEOparse - Parsing ./data/GSE48964_family.soft.gz:
# 09-Oct-2017 16:22:38 DEBUG GEOparse - DATABASE: GeoMiame
# 09-Oct-2017 16:22:38 DEBUG GEOparse - SERIES: GSE48964
# 09-Oct-2017 16:22:38 DEBUG GEOparse - PLATFORM: GPL6244
# 09-Oct-2017 16:22:40 DEBUG GEOparse - SAMPLE: GSM1187673
# 09-Oct-2017 16:22:40 DEBUG GEOparse - SAMPLE: GSM1187674
# 09-Oct-2017 16:22:40 DEBUG GEOparse - SAMPLE: GSM1187675
# 09-Oct-2017 16:22:40 DEBUG GEOparse - SAMPLE: GSM1187676
# 09-Oct-2017 16:22:41 DEBUG GEOparse - SAMPLE: GSM1187677
# 09-Oct-2017 16:22:41 DEBUG GEOparse - SAMPLE: GSM1187678

# %% [markdown]
# # Batch 1 Preprocessing
# Batch 1 is composed of five different datasets that use 5 different Affymetrix platforms, each one represents a technical replicate.

# %%
plats_1 = list(gse1.gpls.keys())
plats_1
# Out:
# ['GPL91', 'GPL92', 'GPL93', 'GPL94', 'GPL95', 'GPL8300']

# %%
samples1 = list(gse1.gsms.keys()); samples1
gse1.gsms[samples1[0]].columns
# Out:
#                                                 description
# ID_REF
# VALUE     'signal' a measure of the abundance of a trans...
# ABS_CALL  the call in an absolute analysis that indicate...

# %%
samples1 = gse1.phenotype_data[["platform_id", "title"]]; samples1; len(samples1)
sample1 = samples1.groupby(["platform_id"]); sample1.groups
d = {}                        
for l in plats_1:
    print("\nPlatform: "+str(l)+"\n", sample1.get_group(l))
    print("\nPlatform: "+str(l)+"\n", sample1.get_group(l)['title'])
    ls = "".join(list(sample1.get_group(l)['title']))
    lf = re.findall("Lean F", ls)
    of = re.findall("Obese F", ls)
    lm = re.findall("Lean M", ls)
    om = re.findall("Obese M", ls)
    print("LF: ", len(lf), "\nOF: ", len(of), "\nLM: ", len(lm), "\nOM: ", len(om))
    d[l] = {"LF": len(lf), "OF": len(of), "LM": len(lm), "OM": len(om)}
#print(d)
df = pd.DataFrame(d); print(df)
df.sum(axis=1)
df.sum(axis=0)
# Out:
# Platform: GPL91
#           platform_id            title
# GSM47224       GPL91   Lean F 01 subA
# GSM47225       GPL91   Lean F 02 subA
# GSM47226       GPL91   Lean F 03 subA
# GSM47227       GPL91   Lean F 04 subA
# GSM47228       GPL91   Lean F 05 subA
# GSM47234       GPL91   Lean M 01 subA
# GSM47235       GPL91   Lean M 02 subA
# GSM47242       GPL91   Lean M 03 subA
# GSM47256       GPL91   Lean M 04 subA
# GSM47269       GPL91   Lean M 05 subA
# GSM47317       GPL91  Obese F 01 subA
# GSM47319       GPL91  Obese F 02 subA
# GSM47321       GPL91  Obese F 03 subA
# GSM47322       GPL91  Obese F 04 subA
# GSM47323       GPL91  Obese F 05 subA
# GSM47329       GPL91  Obese M 01 subA
# GSM47330       GPL91  Obese M 02 subA
# GSM47331       GPL91  Obese M 03 subA
# GSM47332       GPL91  Obese M 04 subA
#
# Platform: GPL91
#  GSM47224     Lean F 01 subA
# GSM47225     Lean F 02 subA
# GSM47226     Lean F 03 subA
# GSM47227     Lean F 04 subA
# GSM47228     Lean F 05 subA
# GSM47234     Lean M 01 subA
# GSM47235     Lean M 02 subA
# GSM47242     Lean M 03 subA
# GSM47256     Lean M 04 subA
# GSM47269     Lean M 05 subA
# GSM47317    Obese F 01 subA
# GSM47319    Obese F 02 subA
# GSM47321    Obese F 03 subA
# GSM47322    Obese F 04 subA
# GSM47323    Obese F 05 subA
# GSM47329    Obese M 01 subA
# GSM47330    Obese M 02 subA
# GSM47331    Obese M 03 subA
# GSM47332    Obese M 04 subA
# Name: title, dtype: object
# LF:  5
# OF:  5
# LM:  5
# OM:  4
#
# Platform: GPL92
#           platform_id            title
# GSM47347       GPL92   Lean F 01 subB
# GSM47348       GPL92   Lean F 02 subB
# GSM47349       GPL92   Lean F 03 subB
# GSM47350       GPL92   Lean F 04 subB
# GSM47351       GPL92   Lean F 05 subB
# GSM47352       GPL92   Lean F 06 subB
# GSM47353       GPL92   Lean F 07 subB
# GSM47354       GPL92   Lean F 08 subB
# GSM47355       GPL92   Lean F 09 subB
# GSM47356       GPL92   Lean F 10 subB
# GSM47357       GPL92   Lean M 01 subB
# GSM47358       GPL92   Lean M 02 subB
# GSM47359       GPL92   Lean M 03 subB
# GSM47360       GPL92   Lean M 04 subB
# GSM47361       GPL92   Lean M 05 subB
# GSM47362       GPL92   Lean M 06 subB
# GSM47363       GPL92   Lean M 07 subB
# GSM47364       GPL92   Lean M 08 subB
# GSM47365       GPL92   Lean M 09 subB
# GSM47303     GPL8300   Lean M 10 subAv2
# GSM47324     GPL8300  Obese F 06 subAv2
# GSM47325     GPL8300  Obese F 07 subAv2
# GSM47326     GPL8300  Obese F 08 subAv2
# GSM47327     GPL8300  Obese F 09 subAv2
# GSM47328     GPL8300  Obese F 10 subAv2
# GSM47333     GPL8300  Obese M 05 subAv2
# GSM47334     GPL8300  Obese M 06 subAv2
# GSM47335     GPL8300  Obese M 07 subAv2
# GSM47336     GPL8300  Obese M 08 subAv2
# GSM47337     GPL8300  Obese M 09 subAv2
#
# Platform: GPL8300
#  GSM47229     Lean F 06 subAv2
# GSM47230     Lean F 07 subAv2
# GSM47231     Lean F 08 subAv2
# GSM47232     Lean F 09 subAv2
# GSM47233     Lean F 10 subAv2
# GSM47286     Lean M 06 subAv2
# GSM47299     Lean M 07 subAv2
# GSM47300     Lean M 08 subAv2
# GSM47301     Lean M 09 subAv2
# GSM47303     Lean M 10 subAv2
# GSM47324    Obese F 06 subAv2
# GSM47325    Obese F 07 subAv2
# GSM47326    Obese F 08 subAv2
# GSM47327    Obese F 09 subAv2
# GSM47328    Obese F 10 subAv2
# GSM47333    Obese M 05 subAv2
# GSM47334    Obese M 06 subAv2
# GSM47335    Obese M 07 subAv2
# GSM47336    Obese M 08 subAv2
# GSM47337    Obese M 09 subAv2
# Name: title, dtype: object
# LF:  5
# OF:  5
# LM:  5
# OM:  5
#     GPL8300  GPL91  GPL92  GPL93  GPL94  GPL95
# LF        5      5     10     10     10     10
# LM        5      5     10     10     10     10
# OF        5      5     10     10     10     10
# OM        5      4      9      9      9      9
# GPL8300    20
# GPL91      19
# GPL92      39
# GPL93      39
# GPL94      39
# GPL95      39
# dtype: int64

# %%
t8300 = sample1.get_group("GPL8300")[["title"]]#; t8300
t91 = sample1.get_group("GPL91")[["title"]]#; t91
t92 = sample1.get_group("GPL92")[["title"]]#; t92
t93 = sample1.get_group("GPL93")[["title"]]#; t93
t94 = sample1.get_group("GPL94")[["title"]]#; t94
t95 = sample1.get_group("GPL95")[["title"]]#; t95

# %%
samples8300 = gse1.pivot_samples('VALUE')[list(t8300.index)]#; samples8300.head()
samples91 = gse1.pivot_samples('VALUE')[list(t91.index)]#; samples91.head()
samples92 = gse1.pivot_samples('VALUE')[list(t92.index)]#; samples92.head()
samples93= gse1.pivot_samples('VALUE')[list(t93.index)]#; samples93.head()
samples94 = gse1.pivot_samples('VALUE')[list(t94.index)]#; samples94.head()
samples95 = gse1.pivot_samples('VALUE')[list(t95.index)]#; samples95.head()

# %%
# annotate with GPL
samples8300_annotated = samples8300.reset_index().merge(gse1.gpls['GPL8300'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples8300_annotated.head()
del samples8300_annotated["ID"]; samples8300_annotated.head()
# remove probes without ENTREZ
samples8300_annotated = samples8300_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples8300_annotated = samples8300_annotated[~samples8300_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples8300_annotated = samples8300_annotated.groupby("ENTREZ_GENE_ID").median(); samples8300_annotated.shape
# Out:
# (8592, 20)

# %%
# annotate with GPL
samples91_annotated = samples91.reset_index().merge(gse1.gpls['GPL91'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples91_annotated.head()
del samples91_annotated["ID"]; samples91_annotated.head()
# remove probes without ENTREZ
samples91_annotated = samples91_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples91_annotated = samples91_annotated[~samples91_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples91_annotated = samples91_annotated.groupby("ENTREZ_GENE_ID").median(); samples91_annotated.shape
# Out:
# (8591, 19)

# %%
# annotate with GPL
samples92_annotated = samples92.reset_index().merge(gse1.gpls['GPL92'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples92_annotated.head()
del samples92_annotated["ID"]; samples92_annotated.head()
# remove probes without ENTREZ
samples92_annotated = samples92_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples92_annotated = samples92_annotated[~samples92_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples92_annotated = samples92_annotated.groupby("ENTREZ_GENE_ID").median(); samples92_annotated.shape
# Out:
# (6547, 39)

# %%
# annotate with GPL
samples93_annotated = samples93.reset_index().merge(gse1.gpls['GPL93'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples93_annotated.head()
del samples93_annotated["ID"]; samples93_annotated.head()
# remove probes without ENTREZ
samples93_annotated = samples93_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples93_annotated = samples93_annotated[~samples93_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples93_annotated = samples93_annotated.groupby("ENTREZ_GENE_ID").median(); samples93_annotated.shape
# Out:
# (5229, 39)

# %%
# annotate with GPL
samples94_annotated = samples94.reset_index().merge(gse1.gpls['GPL94'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples94_annotated.head()
del samples94_annotated["ID"]; samples94_annotated.head()
# remove probes without ENTREZ
samples94_annotated = samples94_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples94_annotated = samples94_annotated[~samples94_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples94_annotated = samples94_annotated.groupby("ENTREZ_GENE_ID").median(); samples94_annotated.shape
# Out:
# (3905, 39)

# %%
# annotate with GPL
samples95_annotated = samples95.reset_index().merge(gse1.gpls['GPL95'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples95_annotated.head()
del samples95_annotated["ID"]; samples95_annotated.head()
# remove probes without ENTREZ
samples95_annotated = samples95_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples95_annotated = samples95_annotated[~samples95_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples95_annotated = samples95_annotated.groupby("ENTREZ_GENE_ID").median(); samples95_annotated.head()
# Out:
#                 GSM47823  GSM47824  GSM47825  GSM47826  GSM47827  GSM47828  \
# ENTREZ_GENE_ID
# 10000              410.9    1576.6     456.0     523.2    1597.5     809.1
# 100009676          972.1     765.0     931.5     567.3     428.1    3066.2
# 10001              907.4     746.9     308.0     481.1     352.5     744.6
# 10003              601.7     350.7     992.6    1495.1    1187.6     972.2
# 10004             4765.8    6540.3    6495.5    6324.6    5901.0    5169.8
#
#                 GSM47829  GSM47830  GSM47831  GSM47832    ...     GSM47852  \
# ENTREZ_GENE_ID                                            ...
# 10000              922.2    1528.2     260.8     629.0    ...        258.2
# 100009676          808.5    2089.9     752.5     622.1    ...       1320.4
# 10001              697.1     205.3     534.7     804.6    ...        394.8
# 10003              744.9     761.9     252.3    1207.1    ...        507.2
# 10004             4312.7    4194.8    4806.7    6314.8    ...       5840.1
#
#                 GSM47853  GSM47854  GSM47855  GSM47856  GSM47857  GSM47858  \
# ENTREZ_GENE_ID
# 10000             1282.4    1188.5    1861.8    1023.3     872.8     314.8
# 100009676         1423.2    1894.8    1907.5    1646.7     985.2     571.6
# 10001              650.8     878.8    1001.7     908.5     429.0     148.1
# 10003              220.7      85.1     855.1     200.7     269.0     620.3
# 10004             5865.8    3593.2    3630.7    5818.2    5956.4    6243.0
#
#                 GSM47859  GSM47860  GSM47861
# ENTREZ_GENE_ID
# 10000              409.2    1087.5     187.3
# 100009676         3064.4    1578.5    2390.9
# 10001              261.9     571.9     128.4
# 10003              734.1      74.3     561.7
# 10004             7691.1    6141.6    5837.7
#
# [5 rows x 39 columns]

# %%
len(set.intersection(set(samples8300_annotated.index), set(samples91_annotated.index), set(samples92_annotated.index), set(samples93_annotated.index), set(samples94_annotated.index), set(samples95_annotated.index)))
# Out:
# 72

# %%
s = [samples8300_annotated, samples91_annotated, samples92_annotated, samples93_annotated, samples94_annotated, samples95_annotated]

# %%
df_final = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True, how='outer'), s)

# %%
samples1 = gse1.phenotype_data[["platform_id", "title"]]; samples1; len(samples1)-
# Out:
# 195

# %%
s = samples1[['title', 'platform_id']]; s.head()
s['title'] = s['title'].apply(lambda x: re.split(' sub*', x)[0]); s.head()
s['mod'] = s['title'].apply(lambda x: re.split(' ', x)); s.head()
s['clinical_status'] = s['mod'].apply(lambda x: x[0]); s.head()
s['gender'] = s['mod'].apply(lambda x: x[1]); s.head()
s['replicate'] = s['mod'].apply(lambda x: x[2]); s.head()
del s['mod']; s.head()
s_gr = s.groupby('title')   #s_gr.get_group('Lean F 01')

# %%
list(s_gr.groups.keys()); s_gr.first().shape
dff = s_gr.first()
dff = df_final.T
dff.head()
dff = s.merge(dff, left_index=True, right_index=True); dff.head()
dff.drop(['platform_id', 'clinical_status', 'gender', 'replicate'], axis=1, inplace=True)
dff.head()
dff_grouped = dff.groupby(['title']).mean()
dff_grouped.head(); dff_grouped.shape

#dff_grouped        :expression series               
#s                  :annotation series
# Out:
# (39, 18281)

# %%
with open('./output/batch1_exprs.txt', 'w') as handle:
    dff_grouped.to_csv(handle, sep='\t')

# %%
with open('./output/batch1_ann.txt', 'w') as handle:
    s.to_csv(handle, sep='\t')

# %% [markdown]
# # Batch 2 Preprocessing

# %%
plats_2 = list(gse2.gpls.keys())[0]
plats_2
# Out:
# 'GPL570'

# %%
samples2 = gse2.phenotype_data[["characteristics_ch1.2.stimulation", "characteristics_ch1.3.resistance status"]]
samples2.head(); len(samples2)
# Out:
# 20

# %%
samples2 = samples2.rename(columns={'characteristics_ch1.2.stimulation':'fasting_status',
                         'characteristics_ch1.3.resistance status':'insulin_status'})
samples2.head()
samples2['cbmi'] = samples2['insulin_status'].apply(lambda x: 'obese' if x == 'resistant' else 'lean')
samples2.head()
# Out:
#           fasting_status insulin_status   cbmi
# GSM655603        fasting      resistant  obese
# GSM655604        fasting      resistant  obese
# GSM655605        fasting      resistant  obese
# GSM655606        fasting      resistant  obese
# GSM655607        fasting      resistant  obese

# %%
h = pd.read_pickle("./data/GSE26637_geno.p")
h.head()
q = pd.read_pickle("./data/GSE26637_pheno.p")
q.head()
# Out:
#            cbmi insulin_status fasting_status
# GSM655608  lean      sensitive        fasting
# GSM655609  lean      sensitive        fasting
# GSM655610  lean      sensitive        fasting
# GSM655611  lean      sensitive        fasting
# GSM655612  lean      sensitive        fasting

# %%
samples570 = gse2.pivot_samples('VALUE')[list(samples2.index)]; samples570.head()

# annotate with GPL
samples570_annotated = samples570.reset_index().merge(gse2.gpls['GPL570'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples570_annotated.head()
del samples570_annotated["ID"]; samples570_annotated.head()
# remove probes without ENTREZ
samples570_annotated = samples570_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples570_annotated = samples570_annotated[~samples570_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples570_annotated = samples570_annotated.groupby("ENTREZ_GENE_ID").median(); samples570_annotated.shape
# Out:
# (20486, 20)

# %%
with open('./output/batch2_exprs.txt', 'w') as handle:
    samples570_annotated.T.to_csv(handle, sep='\t')
    
with open('./output/batch2_ann.txt', 'w') as handle:
    samples2.to_csv(handle, sep='\t')

# %% [markdown]
# # Batch 3 Preprocessing

# %%
plats_3 = list(gse3.gpls.keys())[0]
plats_3
# Out:
# 'GPL570'

# %%
samples3 = gse3.phenotype_data["characteristics_ch1.1.bmi"]
samples3.head(); len(samples3)
samples3 = pd.DataFrame(samples3); samples3.head()
samples3.rename(columns={"characteristics_ch1.1.bmi":"bmi"}, inplace=True)
samples3["cbmi"] = samples3["bmi"].apply(lambda x: "obese" if (float(x) > 30) else ("lean" if (float(x) > 18.5) & (float(x) <= 25) else ("overweight" if (float(x) > 25) & (float(x) <= 30) else "STRANGE")) )
samples3.head();samples3.shape
# Out:
# (33, 2)

# %%
samples3_570 = gse3.pivot_samples('VALUE')[list(samples3.index)]; samples3_570.head()
# Out:
# name       GSM691122  GSM691123  GSM691124  GSM691125  GSM691126  GSM691127  \
# ID_REF
# 1007_s_at   7.004583   7.659500   7.430517   7.771238   7.683040   7.879629
# 1053_at     5.285030   5.253187   5.492071   5.738101   5.643463   5.356738
# 117_at      5.607604   5.476518   5.753545   5.453142   6.431755   4.901203
# 121_at      6.942938   7.450646   7.004481   7.251976   6.931031   7.162552
# 1255_g_at   2.840260   2.948136   2.827350   2.663054   2.610417   2.978128
#
# name       GSM691128  GSM691129  GSM691130  GSM691131    ...      GSM691145  \
# ID_REF                                                   ...
# 1007_s_at   7.184948   7.124926   7.498073   7.687856    ...       7.767611
# 1053_at     5.775912   5.640174   5.262772   5.704770    ...       5.200273
# 117_at      6.298175   6.155661   5.073436   5.634631    ...       5.401797
# 121_at      6.570954   7.042676   6.968916   7.077937    ...       6.758132
# 1255_g_at   2.493905   2.745614   2.742668   2.670149    ...       2.837239
#
# name       GSM691146  GSM691147  GSM691148  GSM691149  GSM691150  GSM691151  \
# ID_REF
# 1007_s_at   7.769750   7.759780   7.925825   7.588576   8.013171   8.301649
# 1053_at     5.121898   5.655970   5.334950   5.479950   5.342561   5.664976
# 117_at      5.456835   5.242564   5.484471   4.999941   5.076155   5.034425
# 121_at      7.080725   7.290405   6.689023   6.793457   6.604402   7.339816
# 1255_g_at   2.766161   2.756533   2.719723   2.866922   2.704116   2.713577
#
# name       GSM691152  GSM691153  GSM691154
# ID_REF
# 1007_s_at   8.516437   7.764079   7.935316
# 1053_at     5.385453   5.530938   5.611537
# 117_at      5.414035   5.414752   5.142741
# 121_at      7.106812   6.752074   6.854420
# 1255_g_at   2.726565   2.589001   2.567418
#
# [5 rows x 33 columns]

# %%
# annotate with GPL
samples3_570_annotated = samples3_570.reset_index().merge(gse3.gpls['GPL570'].table[["ID", "ENTREZ_GENE_ID"]],
                                left_on='ID_REF', right_on="ID").set_index('ID_REF'); samples3_570_annotated.head()
del samples3_570_annotated["ID"]; samples3_570_annotated.head()
# remove probes without ENTREZ
samples3_570_annotated = samples3_570_annotated.dropna(subset=["ENTREZ_GENE_ID"])
# remove probes with more than one gene assigned
samples3_570_annotated = samples3_570_annotated[~samples3_570_annotated.ENTREZ_GENE_ID.str.contains("///")]
# for each gene average LFC over probes
samples3_570_annotated = samples3_570_annotated.groupby("ENTREZ_GENE_ID").median(); samples3_570_annotated.shape
samples3_570_annotated.head()
# Out:
#                 GSM691122  GSM691123  GSM691124  GSM691125  GSM691126  \
# ENTREZ_GENE_ID
# 1                4.202563   3.853392   4.005799   3.775287   3.988817
# 10               3.611358   3.900851   3.670345   3.989030   3.699571
# 100              5.526316   5.553305   5.527924   5.899559   5.844783
# 1000             3.781192   3.881830   3.518877   3.740666   3.540397
# 10000            4.521154   4.355984   4.752987   4.277416   4.410266
#
#                 GSM691127  GSM691128  GSM691129  GSM691130  GSM691131  \
# ENTREZ_GENE_ID
# 1                4.074538   3.789106   3.985469   4.202136   3.929663
# 10               4.050322   3.687475   3.788186   4.230811   4.020388
# 100              5.752965   6.008601   5.560185   6.149886   6.078632
# 1000             3.609309   3.587624   3.610829   3.501181   3.365197
# 10000            4.467307   4.573366   4.229275   4.221578   4.362966
#
#                   ...      GSM691145  GSM691146  GSM691147  GSM691148  \
# ENTREZ_GENE_ID    ...
# 1                 ...       4.035109   4.505537   3.688537   4.021974
# 10                ...       4.260082   3.755154   4.273325   3.764177
# 100               ...       6.150959   5.858245   6.099553   6.562532
# 1000              ...       3.537610   3.925105   3.738994   3.721691
# 10000             ...       4.302391   4.348741   4.414892   4.134308
#
#                 GSM691149  GSM691150  GSM691151  GSM691152  GSM691153  \
# ENTREZ_GENE_ID
# 1                3.859197   4.016395   3.853851   3.905869   3.933165
# 10               3.931262   3.856003   3.631455   3.812028   4.106960
# 100              6.097076   5.970264   5.229485   5.441216   6.344840
# 1000             3.315593   3.471609   3.578582   3.718983   3.683929
# 10000            4.327611   4.488344   4.229990   4.791674   4.489651
#
#                 GSM691154
# ENTREZ_GENE_ID
# 1                3.731458
# 10               4.014231
# 100              6.026648
# 1000             3.618684
# 10000            4.827196
#
# [5 rows x 33 columns]

# %%
with open('./output/batch3_exprs.txt', 'w') as handle:
    samples3_570_annotated.T.to_csv(handle, sep='\t')

# %% [markdown]
# # Batch 4 Preprocessing

# %%
plats_4 = list(gse4.gpls.keys())[0]
plats_4
# Out:
# 'GPL6244'

# %%
#####################################################################
#                   ANNOTATIONS
#####################################################################

samples4 = gse4.phenotype_data["source_name_ch1"]
samples4 = pd.DataFrame(samples4); samples4.head()
samples4.rename(columns={"source_name_ch1":"cbmi"}, inplace=True); samples4.head()
samples4["cbmi"] = samples4["cbmi"].apply(lambda x: x.split(' ')[1]); samples4.head()
print(samples4.head()); print(len(samples4))
print(samples4.shape)
# Out:
#                  cbmi
# GSM1187673      obese
# GSM1187674      obese
# GSM1187675      obese
# GSM1187676  non-obese
# GSM1187677  non-obese
# 6
# (6, 1)

# %%
             
with open('./output/batch4_ann.txt', 'w') as handle:
    samples4.to_csv(handle, sep='\t')

# %%
samples4_6244 = gse4.pivot_samples('VALUE')[list(samples4.index)]; samples4_6244.head() 
anns_4 = gse4.gpls['GPL6244'].table[["ID", "GB_LIST"]].dropna(); anns_4.head()
anns_4['refs'] = anns_4['GB_LIST'].apply(lambda x: x.split(','))
anns_4.head()
anns_4['an_bool'] = anns_4['refs'].apply(lambda x: False if len(x)>1 else True)
anns_4 = anns_4[anns_4['an_bool']==True].apply(lambda x: x,axis=0)
print(anns_4.head())
anns_4.shape
# Out:
#          ID    GB_LIST         refs  an_bool
# 6   7896748  NC_001807  [NC_001807]     True
# 7   7896750  NC_001807  [NC_001807]     True
# 17  7896859  NR_029639  [NR_029639]     True
# 18  7896861  NR_029834  [NR_029834]     True
# 19  7896863  NR_029957  [NR_029957]     True
# (2400, 4)

# %%
with open('./output/batch4_exprs.txt', 'w') as handle:
    anns_4.T.to_csv(handle, sep='\t')
